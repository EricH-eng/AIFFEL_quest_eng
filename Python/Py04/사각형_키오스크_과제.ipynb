# %%
#사각형 넓이 구하기

# %%
class Square:
    def __init__(self):
        self.square = int(input('넓이를 구하고 싶은 사각형의 숫자를 써주세요.\n 1.직사각형 2.평행사변형 3.사다리꼴 \n >>>'))

        if self.square == 1:
            print('직사각형 함수는 rect()입니다.')

        elif self.square == 2:
            print('평행사변형 함수는 par()입니다.')
        
        elif self.square == 3:
            print('사다리꼴 함수는 trape()입니다.')
        
        else:
            print('1, 2, 3 중에서 다시 입력해주세요')

    def rect(self):
        width, vertical = map(int, input('가로, 세로를 입력하세요. 예시 : 가로,세로\n >>>').split(','))
        area = width * vertical
        result = '직사각형의 넓이는 : ' + str(area)
        return result

    def par(self):
        base, height = map(int, input('밑변, 높이를 입력하세요. 예시: 밑변, 높이 \n >>>').split(','))
        area = base * height
        result = '평행사변형의 넓이는 : ' + str(area)
        return result

    def trape(self):
        top, bottom, height = map(int, input('밑변, 윗변, 높이를 입력하세요. 예시: 밑변, 윗변, 높이 \n >>>').split(','))
        area = (top + bottom) * height / 2
        result = '사다리골의 넓이는 : ' + str(area)
        return result

# %%
a = Square()
# Out:
# 넓이를 구하고 싶은 사각형의 숫자를 써주세요.
#  1.직사각형 2.평행사변형 3.사다리꼴
#  >>> 1
# 직사각형 함수는 rect()입니다.

# %%
a.rect()
# Out:
# 가로, 세로를 입력하세요. 예시 : 가로,세로
#  >>> 1,2
# '직사각형의 넓이는 : 2'

# %%
a.par()
# Out:
# 밑변, 높이를 입력하세요. 예시: 밑변, 높이
#  >>> 1,2
# '평행사변형의 넓이는 : 2'

# %%
a.trape()
# Out:
# 밑변, 윗변, 높이를 입력하세요. 예시: 밑변, 윗변, 높이
#  >>> 1,2,3
# '사다리골의 넓이는 : 4.5'

# %%
#키오스크

# %%
class Kiosk:
    def __init__(self):
        self.menu = ['아메리카노', '카페라떼', '아이스티']
        self.price = [3000, 3500, 2500]
        self.order_menu = [] 
        self.order_price = []
        
    # 메뉴 출력 메서드
    def menu_print(self):
        for i in range(len(self.menu)):
            print(i+1, self.menu[i], ':', self.price[i], '원')

    # 주문 메서드
    def menu_select(self):
        while True:
            n = 0
            while n < 1 or len(self.menu) < n:
                n = int(input("음료 번호를 입력하세요 : "))

                if 1 <= n & n <= len(self.menu):
                    self.price_sum = self.price[n-1]
                else:
                    print("없는 메뉴입니다. 다시 주문해주세요")
        
            t = 0
            while t != 1 and t != 2:
                t = int(input("HOT 음료는 1을, ICE 음료는 2를 입력하세요 : "))

                if t == 1:
                    self.temp = "HOT"
                elif t == 2:
                    self.temp = "ICE"
                else:
                    print("1과 2 중 하나를 입력하세요.")

            self.order_price.append(self.price[n-1])
            self.order_menu.append(self.temp + ' ' + self.menu[n-1])
        
            print(self.order_menu, self.order_price)

            again = input("추가 주문하시겠습니까? (y/n) : ")
            if again != 'y':
                break

    # 지불
    def pay(self):
        payment = input("결제 수단을 입력하세요.")

        if payment in ['1', "cash"]:
            print("직원을 호출하겠습니다.")
        elif payment in ['2', "card"]:
            print("IC칩 방향에 맞게 카드를 꼳아주세요.")
        else:
            print("다시 결제를 시도해 주세요.")
            

    # 주문서 출력 
    def table(self):
        print('⟝' + '-' * 30 + '⟞')
        for i in range(5):
            print('|' + ' ' * 31 + '|')
         
        for i in range(len(self.order_menu)):
            print(self.order_menu[i], ' : ', self.order_price[i])

        for i in range(5):
            print('|' + ' ' * 31+ '|')
        print('⟝' + '-' * 30 + '⟞')

b = Kiosk() 
b.menu_print()
b.menu_select()
b.pay()
b.table()
# Out:
# 1 아메리카노 : 3000 원
# 2 카페라떼 : 3500 원
# 3 아이스티 : 2500 원
# 음료 번호를 입력하세요 :  1
# HOT 음료는 1을, ICE 음료는 2를 입력하세요 :  2
# ['ICE 아메리카노'] [3000]
# 추가 주문하시겠습니까? (y/n) :  n
# 결제 수단을 입력하세요. 1
# 직원을 호출하겠습니다.
# ⟝------------------------------⟞
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ICE 아메리카노  :  3000
# |                               |
# |                               |
# |                               |
# |                               |
# |                               |
# ⟝------------------------------⟞
